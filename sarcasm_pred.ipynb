# %%
import json
array = []
with open("sarcasm.json", 'r') as f:
    for line in f:
        array.append(json.loads(line))
    
sentences = []
labels = []
urls = []

for item in array:
    sentences.append(item["headline"])
    labels.append(item["is_sarcastic"])
    urls.append(item["article_link"])

# %%
training_size = 20000

# %%
training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]

training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# %%
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 100
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# %%
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
import numpy as np
training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 16)           160000
#
#  global_average_pooling1d (  (None, 16)                0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 24)                408
#
#  dense_1 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 160433 (626.69 KB)
# Trainable params: 160433 (626.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
num_epochs = 30
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Epoch 1/30
# 625/625 - 1s - loss: 0.6615 - accuracy: 0.5860 - val_loss: 0.5762 - val_accuracy: 0.7493 - 946ms/epoch - 2ms/step
# Epoch 2/30
# 625/625 - 1s - loss: 0.4331 - accuracy: 0.8266 - val_loss: 0.3861 - val_accuracy: 0.8369 - 616ms/epoch - 986us/step
# Epoch 3/30
# 625/625 - 1s - loss: 0.3072 - accuracy: 0.8792 - val_loss: 0.3518 - val_accuracy: 0.8542 - 612ms/epoch - 979us/step
# Epoch 4/30
# 625/625 - 1s - loss: 0.2529 - accuracy: 0.9016 - val_loss: 0.3433 - val_accuracy: 0.8557 - 609ms/epoch - 974us/step
# Epoch 5/30
# 625/625 - 1s - loss: 0.2170 - accuracy: 0.9164 - val_loss: 0.3491 - val_accuracy: 0.8566 - 609ms/epoch - 974us/step
# Epoch 6/30
# 625/625 - 1s - loss: 0.1904 - accuracy: 0.9279 - val_loss: 0.3533 - val_accuracy: 0.8533 - 604ms/epoch - 967us/step
# Epoch 7/30
# 625/625 - 1s - loss: 0.1693 - accuracy: 0.9376 - val_loss: 0.3686 - val_accuracy: 0.8544 - 604ms/epoch - 966us/step
# Epoch 8/30
# 625/625 - 1s - loss: 0.1509 - accuracy: 0.9453 - val_loss: 0.3872 - val_accuracy: 0.8505 - 601ms/epoch - 961us/step
# Epoch 9/30
# 625/625 - 1s - loss: 0.1353 - accuracy: 0.9530 - val_loss: 0.4298 - val_accuracy: 0.8359 - 602ms/epoch - 963us/step
# Epoch 10/30
# 625/625 - 1s - loss: 0.1226 - accuracy: 0.9574 - val_loss: 0.4246 - val_accuracy: 0.8498 - 610ms/epoch - 976us/step
# Epoch 11/30
# 625/625 - 1s - loss: 0.1119 - accuracy: 0.9609 - val_loss: 0.4472 - val_accuracy: 0.8490 - 608ms/epoch - 973us/step
# Epoch 12/30
# 625/625 - 1s - loss: 0.1004 - accuracy: 0.9658 - val_loss: 0.4793 - val_accuracy: 0.8436 - 603ms/epoch - 965us/step
# Epoch 13/30
# 625/625 - 1s - loss: 0.0917 - accuracy: 0.9697 - val_loss: 0.5114 - val_accuracy: 0.8399 - 603ms/epoch - 965us/step
# Epoch 14/30
# 625/625 - 1s - loss: 0.0845 - accuracy: 0.9721 - val_loss: 0.5368 - val_accuracy: 0.8393 - 614ms/epoch - 982us/step
# Epoch 15/30
# 625/625 - 1s - loss: 0.0773 - accuracy: 0.9750 - val_loss: 0.5708 - val_accuracy: 0.8372 - 614ms/epoch - 982us/step
# Epoch 16/30
# 625/625 - 1s - loss: 0.0702 - accuracy: 0.9785 - val_loss: 0.6018 - val_accuracy: 0.8310 - 614ms/epoch - 982us/step
# Epoch 17/30
# 625/625 - 1s - loss: 0.0645 - accuracy: 0.9802 - val_loss: 0.6364 - val_accuracy: 0.8299 - 610ms/epoch - 976us/step
# Epoch 18/30
# 625/625 - 1s - loss: 0.0587 - accuracy: 0.9815 - val_loss: 0.6694 - val_accuracy: 0.8296 - 600ms/epoch - 960us/step
# Epoch 19/30
# 625/625 - 1s - loss: 0.0551 - accuracy: 0.9819 - val_loss: 0.7148 - val_accuracy: 0.8280 - 606ms/epoch - 969us/step
# Epoch 20/30
# 625/625 - 1s - loss: 0.0506 - accuracy: 0.9839 - val_loss: 0.7454 - val_accuracy: 0.8261 - 607ms/epoch - 971us/step
# Epoch 21/30
# 625/625 - 1s - loss: 0.0458 - accuracy: 0.9858 - val_loss: 0.7978 - val_accuracy: 0.8244 - 611ms/epoch - 978us/step
# Epoch 22/30
# 625/625 - 1s - loss: 0.0432 - accuracy: 0.9868 - val_loss: 0.8213 - val_accuracy: 0.8223 - 610ms/epoch - 975us/step
# Epoch 23/30
# 625/625 - 1s - loss: 0.0389 - accuracy: 0.9887 - val_loss: 0.9041 - val_accuracy: 0.8186 - 611ms/epoch - 977us/step
# Epoch 24/30
# 625/625 - 1s - loss: 0.0352 - accuracy: 0.9901 - val_loss: 0.9074 - val_accuracy: 0.8171 - 614ms/epoch - 982us/step
# Epoch 25/30
# 625/625 - 1s - loss: 0.0333 - accuracy: 0.9906 - val_loss: 0.9542 - val_accuracy: 0.8153 - 609ms/epoch - 974us/step
# Epoch 26/30
# 625/625 - 1s - loss: 0.0289 - accuracy: 0.9923 - val_loss: 0.9941 - val_accuracy: 0.8149 - 609ms/epoch - 974us/step
# Epoch 27/30
# 625/625 - 1s - loss: 0.0295 - accuracy: 0.9913 - val_loss: 1.0365 - val_accuracy: 0.8135 - 614ms/epoch - 983us/step
# Epoch 28/30
# 625/625 - 1s - loss: 0.0268 - accuracy: 0.9920 - val_loss: 1.0646 - val_accuracy: 0.8120 - 613ms/epoch - 980us/step
# Epoch 29/30
# 625/625 - 1s - loss: 0.0249 - accuracy: 0.9931 - val_loss: 1.0990 - val_accuracy: 0.8123 - 614ms/epoch - 983us/step
# Epoch 30/30
# 625/625 - 1s - loss: 0.0240 - accuracy: 0.9926 - val_loss: 1.1844 - val_accuracy: 0.8134 - 610ms/epoch - 976us/step

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
sentence = ["He is such a genius he fails everytime", "game of thrones season finale showing this sunday night"]
sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(model.predict(padded))
# Out:
# 1/1 [==============================] - 0s 15ms/step
# [[9.9750555e-01]
#  [6.1404273e-07]]

# %%
# score = model.predict(padded)
# for i in score:
#     if score[i] >= 0.75:
#         print("sarcastic")
#     i = i+1
